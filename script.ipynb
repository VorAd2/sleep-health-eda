# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
df[['Systolic_BP','Diastolic_BP']] = df['Blood Pressure'].str.split('/', expand= True)
df['Systolic_BP'] = df['Systolic_BP'].astype(float)
df['Diastolic_BP'] = df['Diastolic_BP'].astype(float)

print(df[['Systolic_BP', 'Diastolic_BP']].dtypes)

# %%
df.describe().T
# Out:
#                          count         mean          std     min      25%  \
# Person ID                374.0   187.500000   108.108742     1.0    94.25
# Age                      374.0    42.184492     8.673133    27.0    35.25
# Sleep Duration           374.0     7.132086     0.795657     5.8     6.40
# Quality of Sleep         374.0     7.312834     1.196956     4.0     6.00
# Physical Activity Level  374.0    59.171123    20.830804    30.0    45.00
# Stress Level             374.0     5.385027     1.774526     3.0     4.00
# Heart Rate               374.0    70.165775     4.135676    65.0    68.00
# Daily Steps              374.0  6816.844920  1617.915679  3000.0  5600.00
# Systolic_BP              374.0   128.553476     7.748118   115.0   125.00
# Diastolic_BP             374.0    84.649733     6.161611    75.0    80.00
#
#                             50%      75%      max
# Person ID                 187.5   280.75    374.0
# Age                        43.0    50.00     59.0
# Sleep Duration              7.2     7.80      8.5
# Quality of Sleep            7.0     8.00      9.0
# Physical Activity Level    60.0    75.00     90.0
# Stress Level                5.0     7.00      8.0
# Heart Rate                 70.0    72.00     86.0
# Daily Steps              7000.0  8000.00  10000.0
# Systolic_BP               130.0   135.00    142.0
# Diastolic_BP               85.0    90.00     95.0

# %%
df.describe(include=str).T
# Out:
#                count unique          top freq
# Gender           374      2         Male  189
# Occupation       374     11        Nurse   73
# BMI Category     374      4       Normal  195
# Blood Pressure   374     25       130/85   99
# Sleep Disorder   155      2  Sleep Apnea   78

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  Systolic_BP  \
# 0         126/83          77         4200            NaN        126.0
# 1         125/80          75        10000            NaN        125.0
# 2         125/80          75        10000            NaN        125.0
# 3         140/90          85         3000    Sleep Apnea        140.0
# 4         140/90          85         3000    Sleep Apnea        140.0
#
#    Diastolic_BP
# 0          83.0
# 1          80.0
# 2          80.0
# 3          90.0
# 4          90.0
